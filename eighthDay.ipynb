# %%
import requests 

response = requests.get('https://api.github.com/events')
print(response.json())
print(response.status_code)
print(response.headers)
print(response.headers['Content-Type'])
print(response.text)
print(type(response.text))
# Out:
# [{'id': '52711999662', 'type': 'PushEvent', 'actor': {'id': 35671665, 'login': 'artisticLogicMK', 'display_login': 'artisticLogicMK', 'gravatar_id': '', 'url': 'https://api.github.com/users/artisticLogicMK', 'avatar_url': 'https://avatars.githubusercontent.com/u/35671665?'}, 'repo': {'id': 946165418, 'name': 'artisticLogicMK/torchlight', 'url': 'https://api.github.com/repos/artisticLogicMK/torchlight'}, 'payload': {'repository_id': 946165418, 'push_id': 25810358046, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': 'c50c9a59ab241ee74af5d87688cd528d1a235b43', 'before': '55b7dfbd4c15ecbe030d270fdd5d92a272f1ff08', 'commits': [{'sha': 'c50c9a59ab241ee74af5d87688cd528d1a235b43', 'author': {'email': 'max.2xtremes@gmail.com', 'name': 'artisticLogicMK'}, 'message': '...', 'distinct': True, 'url': 'https://api.github.com/repos/artisticLogicMK/torchlight/commits/c50c9a59ab241ee74af5d87688cd528d1a235b43'}]}, 'public': True, 'created_at': '2025-07-30T04:09:14Z'}, {'id': '5271199
# ...

# %%
if 'application/json' in response.headers.get('Content-Type', ''):
    data = response.json()
    print(data)
    print(type(data))
# Out:
# [{'id': '52711999662', 'type': 'PushEvent', 'actor': {'id': 35671665, 'login': 'artisticLogicMK', 'display_login': 'artisticLogicMK', 'gravatar_id': '', 'url': 'https://api.github.com/users/artisticLogicMK', 'avatar_url': 'https://avatars.githubusercontent.com/u/35671665?'}, 'repo': {'id': 946165418, 'name': 'artisticLogicMK/torchlight', 'url': 'https://api.github.com/repos/artisticLogicMK/torchlight'}, 'payload': {'repository_id': 946165418, 'push_id': 25810358046, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': 'c50c9a59ab241ee74af5d87688cd528d1a235b43', 'before': '55b7dfbd4c15ecbe030d270fdd5d92a272f1ff08', 'commits': [{'sha': 'c50c9a59ab241ee74af5d87688cd528d1a235b43', 'author': {'email': 'max.2xtremes@gmail.com', 'name': 'artisticLogicMK'}, 'message': '...', 'distinct': True, 'url': 'https://api.github.com/repos/artisticLogicMK/torchlight/commits/c50c9a59ab241ee74af5d87688cd528d1a235b43'}]}, 'public': True, 'created_at': '2025-07-30T04:09:14Z'}, {'id': '5271199
# ...

# %%
import requests

response = requests.get('https://api.github.com/events')
if response.status_code == 200:
    print(response.headers['Content-Type'])
    data = response.text
    print(data[:100]) 
    print(type(data))
else:
    print(response.status_code)
# Out:
# application/json; charset=utf-8
# [{"id":"52712427983","type":"PushEvent","actor":{"id":11155705,"login":"zhongfly","display_login":"z
# <class 'str'>

# %%
import requests

data = {'username': 'user', 'password': 'pass'}

response = requests.post('https://httpbin.org/post', data)
if response.status_code == 200:
    print("login successful")
    print(response.text)
# Out:
# login successful
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "pass",
#     "username": "user"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6889a3a6-476945f63e4df2861ee40110"
#   },
#   "json": null,
#   "origin": "175.157.14.132",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests

params = {'userId': 1, 'id': 2}

response = requests.get('https://jsonplaceholder.typicode.com/posts', params=params)
print(response.url)
print(response.text)
# Out:
# https://jsonplaceholder.typicode.com/posts?userId=1&id=2
# [
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#   }
# ]

# %%
username = 'user',
password = 'pass'

response = requests.get('https://httpbin.org/get', auth=(username, password))
if response.status_code == 200:
    print("Authentication successful")
    print(response.text)
# Out:
# Authentication successful
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic KCd1c2VyJywpOnBhc3M=",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6889af6a-6c5e05ad46c6d85e244452c3"
#   },
#   "origin": "175.157.14.132",
#   "url": "https://httpbin.org/get"
# }

# %%
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie&quot; class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie&quot; class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie&quot; class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.title)
print(soup.p) # prints the first <p> tag
print(soup.find('p')) # prints the first <p> tag
print(soup.find_all('p')) # prints all <p> tags
print()
print(soup.a) # prints the first <a> tag
print(soup.find_all('a')) # prints all <a> tags
# Out:
# <title>The Dormouse's story</title>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="title"><b>The Dormouse's story</b></p>
# [<p class="title"><b>The Dormouse's story</b></p>, <p class="story">Once upon a time there were three little sisters; and their names were
# <a href='http://example.com/elsie" class=' id="link1" sister"="">Elsie</a>,
# <a href='http://example.com/lacie" class=' id="link2" sister"="">Lacie</a> and
# <a href='http://example.com/tillie" class=' id="link3" sister"="">Tillie</a>;
# and they lived at the bottom of a well.</p>, <p class="story">...</p>]
#
# <a href='http://example.com/elsie" class=' id="link1" sister"="">Elsie</a>
# [<a href='http://example.com/elsie" class=' id="link1" sister"="">Elsie</a>, <a href='http://example.com/lacie" class=' id="link2" sister"="">Lacie</a>, <a href='http://example.com/tillie" class=' id="link3" sister"="">Tillie</a>]

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.example.com')

if response.status_code == 200:
    print("Page fetched successfully")
    html_doc = response.text

    soup = BeautifulSoup(html_doc, 'html.parser')
    if soup.h1:
        print(soup.h1.text)
    else:
        print("h1 tag Not found")
# Out:
# Page fetched successfully
# Example Domain

# %%
import requests

params = {'latitude' : '6.7175',
          'longitude':'79.9127',
          'current'  : 'temperature_2m,wind_speed_10m'
          }

response = requests.get('https://api.open-meteo.com/v1/forecast',params=params)
if response.status_code == 200:
    print("Weather data fetched successfully")
    print(response.text)
# Out:
# Weather data fetched successfully
# {"latitude":6.875,"longitude":79.875,"generationtime_ms":0.028371810913085938,"utc_offset_seconds":0,"timezone":"GMT","timezone_abbreviation":"GMT","elevation":14.0,"current_units":{"time":"iso8601","interval":"seconds","temperature_2m":"°C","wind_speed_10m":"km/h"},"current":{"time":"2025-07-30T09:30","interval":900,"temperature_2m":27.4,"wind_speed_10m":21.9}}

# %%
import requests

def fetchWeather(latitude, longitude, current):

    params = {  'latitude' : latitude,
                'longitude': longitude,
                'current'  : current
              }

    response = requests.get('https://api.open-meteo.com/v1/forecast', params=params)
    if response.status_code == 200:
      print("Weather data fetched successfully")
      return response.json()
    else:
      print("Failed to fetch weather data", response.status_code)


def parse_weather_data(data):
    if 'current' in data:
        current = data['current']
        temperature = current.get('temperature_2m')
        wind_speed = current.get('wind_speed_10m')
        return f"Temperature: {temperature} C, Wind Speed: {wind_speed} Km/h"
    else:
        return "No current weather data available"
    
def parse_weather_data2(data):
   if data is None or 'current' not in data:
       print("No current weather data available")
       return None    
   current_weather = data['current']['temperature_2m']
   wind_speed = data['current']['wind_speed_10m'] 
   return f"Temperature: {current_weather} C, Wind Speed: {wind_speed} Km/h"


weather_data = fetchWeather(6.7175, 79.9127, 'temperature_2m,wind_speed_10m') 
parse_weather_data = parse_weather_data(weather_data)
parse_weather_data2 = parse_weather_data2(weather_data)
print(weather_data)         
print(parse_weather_data)
print(parse_weather_data2)
# Out:
# Weather data fetched successfully
# {'latitude': 6.875, 'longitude': 79.875, 'generationtime_ms': 0.0286102294921875, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 14.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C', 'wind_speed_10m': 'km/h'}, 'current': {'time': '2025-07-30T10:15', 'interval': 900, 'temperature_2m': 27.5, 'wind_speed_10m': 24.0}}
# Temperature: 27.5 C, Wind Speed: 24.0 Km/h
# Temperature: 27.5 C, Wind Speed: 24.0 Km/h
